# %%
import sys
from pathlib import Path

# Add project root to Python path
# In Jupyter notebooks, go up one level from notebooks/ directory
cwd = Path.cwd()
if cwd.name == 'notebooks':
    project_root = cwd.parent
else:
    # If already at project root, use it directly
    project_root = cwd

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.pipeline import run_job_finder

query = '"AI startup" ("about us" OR "company" OR "who we are") -news -blog -article -wikipedia -linkedin -medium'
rows = run_job_finder(query, limit_companies=10)

rows, len(rows)
# Out:
# ([{'title': 'About Us',
#    'source_url': 'https://www.sravathi.ai/about',
#    'homepage': 'https://www.sravathi.ai',
#    'careers_url': None},
#   {'title': 'Artificial Intelligence, IT Company, AI Startup - Alpha AI',
#    'source_url': 'https://alphaai.biz/our-story',
#    'homepage': 'https://alphaai.biz',
#    'careers_url': 'https://alphaai.biz/careers'},
#   {'title': 'AI NATION ABOUT US',
#    'source_url': 'https://www.ai-nation.de/about-us',
#    'homepage': 'https://www.ai-nation.de',
#    'careers_url': None},
#   {'title': 'Innovators in Codeless AI and Cybersecurity Solutions',
#    'source_url': 'https://www.usai.io/about-us/',
#    'homepage': 'https://www.usai.io',
#    'careers_url': 'https://www.usai.io/careers'},
#   {'title': 'About Us - Google for Startups',
#    'source_url': 'https://startup.google.com/about-us/',
#    'homepage': 'https://startup.google.com',
#    'careers_url': 'https://startup.google.com/community'},
#   {'title': 'Voice AI company SuperDial picks up $15M series A',
#    'source_url': 'https://www.fiercehealthcare.com/ai-and-machine-learning/voice-ai-company-superdial-picks-15m-series-automate-insurance-calls',
#    'homepage': 'https://www.fiercehealthcare.com',
#    'careers_url': 'https://www.fiercehealthcare.com/providers/hospital-groups-file-lawsuit-enjoin-pharma-supported-340b-rebate-pilot'},
#   {'title': 'Top 1262 Artificial Intelligence/1000 Startups 2026',
#    'source_url': 'https://topstartups.io/?industries=Artificial%20Intelligence/1000',
#    'homepage': 'https://topstartups.io',
#    'careers_url': 'https://topstartups.io/jobs'}],
#  7)

# %%
sum(1 for r in rows if r["careers_url"]), rows[:3]
# Out:
# (5,
#  [{'title': 'About Us',
#    'source_url': 'https://www.sravathi.ai/about',
#    'homepage': 'https://www.sravathi.ai',
#    'careers_url': None},
#   {'title': 'Artificial Intelligence, IT Company, AI Startup - Alpha AI',
#    'source_url': 'https://alphaai.biz/our-story',
#    'homepage': 'https://alphaai.biz',
#    'careers_url': 'https://alphaai.biz/careers'},
#   {'title': 'AI NATION ABOUT US',
#    'source_url': 'https://www.ai-nation.de/about-us',
#    'homepage': 'https://www.ai-nation.de',
#    'careers_url': None}])
